# %% [markdown]
# <a href="https://colab.research.google.com/github/yhy0519/Machine_learning_of_R/blob/main/R01_01_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **■ R 설치**
#
# https://ftp.harukasan.org/CRAN/
#
# 마우스 오른쪽 -> 관리자 권한으로 실행
# 편집 --> GUI 설정에서 글씨 크기를 바꾸세요
#
# emp3.csv 를 R 로 로드합니다.

# %%
setwd('/content/data')
getwd()
# Out:
# [1] "/content/data"

# %% [markdown]
# emp3.csv 를 'content/data' 에 둔다.

# %%
emp <- read.csv("/content/data/emp3.csv", header=T)
emp
# Out:
#    index empno ename  job       mgr  hiredate        sal  comm deptno
# 1   1    7839  KING   PRESIDENT   NA 1981-11-17 0:00 5000   NA 10
# 2   2    7698  BLAKE  MANAGER   7839 1981-05-01 0:00 2850   NA 30
# 3   3    7782  CLARK  MANAGER   7839 1981-05-09 0:00 2450   NA 10
# 4   4    7566  JONES  MANAGER   7839 1981-04-01 0:00 2975   NA 20
# 5   5    7654  MARTIN SALESMAN  7698 1981-09-10 0:00 1250 1400 30
# 6   6    7499  ALLEN  SALESMAN  7698 1981-02-11 0:00 1600  300 30
# 7   7    7844  TURNER SALESMAN  7698 1981-08-21 0:00 1500    0 30
# 8   8    7900  JAMES  CLERK     7698 1981-12-11 0:00  950   NA 30
# 9   9    7521  WARD   SALESMAN  7698 1981-02-23 0:00 1250  500 30
# 10 10    7902  FORD   ANALYST   7566 1981-12-11 0:00 3000   NA 20
# 11 11    7369  SMITH  CLERK     7902 1980-12-09 0:00  800   NA 20
# 12 12    7788  SCOTT  ANALYST   7566 1982-12-22 0:00 3000   NA 20
# 13 13    7876  ADAMS  CLERK     7788 1983-01-15 0:00 1100   NA 20
# ...

# %% [markdown]
# emp 데이터의 월급으로 원형 그래프를 그리시오 !

# %%
pie(emp$sal, col=rainbow(14))
# Out:
# plot without title

# %% [markdown]
# **■ R studio 설치**
#
# 구글에서 R studio 설치라고 검색하고 설치하세요 ~~
#
# https://rstudio.com/products/rstudio/download/

# %% [markdown]
# 문제1. centos7 에 R 과 Rstudio 를 설치하고 결과화면을 캡쳐하기  (모두 root 에서 실행)
#
# centos 에 R 과 Rstudio 설치
# https://flipdata.tistory.com/35
#
#
# Rstudio 설치
# (https://rstudio.com/products/rstudio/download-server/redhat-centos/)
#
#     # wget https://download2.rstudio.org/server/centos7/x86_64/rstudio-server-rhel-1.4.1103-x86_64.rpm
#     # sudo yum install rstudio-server-rhel-1.4.1103-x86_64.rpm
#
# putty 에서 R studio 실행할때만 아래와 같이 하면됩니다.
#
#     [root@centos ~]# export DISPLAY=192.168.0.11:0.0
#     [root@centos ~]# firefox http://localhost:8787
#     Running without a11y support!
#
# R>
#
#     setwd("/home/scott")
#     emp <- read.csv("emp2.csv")
#     emp
#
#
# ![image.png](data:image/png;base64,...)
